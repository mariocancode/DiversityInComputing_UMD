# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
jour_gender = pd.read_csv("jour_gender.csv")
jour_gender
# Out:
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count
# 0   2016                 Female                     Female    300
# 1   2016                   Male                       Male    177
# 2   2017                 Female                     Female    274
# 3   2017                   Male                       Male    185
# 4   2018                 Female                     Female    281
# 5   2018                   Male                       Male    182
# 6   2019                 Female                     Female    301
# 7   2019                   Male                       Male    168
# 8   2020                 Female                     Female    284
# 9   2020                   Male                       Male    158
# 10  2021                 Female                     Female    271
# 11  2021                   Male                       Male    175
# 12  2022                 Female                     Female    266
# ...

# %%
cmns_gender = pd.read_csv("cmns_gender.csv")
cmns_gender
# Out:
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count
# 0   2016                 Female                     Female   2123
# 1   2016                   Male                       Male   3661
# 2   2017                 Female                     Female   2281
# 3   2017                   Male                       Male   3938
# 4   2018                 Female                     Female   2460
# 5   2018                   Male                       Male   4122
# 6   2019                 Female                     Female   2554
# 7   2019                   Male                       Male   3952
# 8   2020                 Female                     Female   2605
# 9   2020                   Male                       Male   3920
# 10  2021                 Female                     Female   2538
# 11  2021                   Male                       Male   3823
# 12  2022                 Female                     Female   2567
# ...

# %%
info_gender = pd.read_csv("info_gender.csv")
info_gender
# Out:
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count
# 0   2016                 Female                     Female     24
# 1   2016                   Male                       Male     67
# 2   2017                 Female                     Female    103
# 3   2017                   Male                       Male    264
# 4   2018                 Female                     Female    210
# 5   2018                   Male                       Male    499
# 6   2019                 Female                     Female    286
# 7   2019                   Male                       Male    673
# 8   2020                 Female                     Female    331
# 9   2020                   Male                       Male    829
# 10  2021                 Female                     Female    372
# 11  2021                   Male                       Male    835
# 12  2022                 Female                     Female    447
# ...

# %%
bmgt_gender = pd.read_csv("bmgt_gender.csv")
bmgt_gender
# Out:
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count
# 0   2016                 Female                     Female   1231
# 1   2016                   Male                       Male   1692
# 2   2017                 Female                     Female   1193
# 3   2017                   Male                       Male   1701
# 4   2018                 Female                     Female   1208
# 5   2018                   Male                       Male   1731
# 6   2019                 Female                     Female   1218
# 7   2019                   Male                       Male   1683
# 8   2020                 Female                     Female   1237
# 9   2020                   Male                       Male   1663
# 10  2021                 Female                     Female   1351
# 11  2021                   Male                       Male   1653
# 12  2022                 Female                     Female   1441
# ...

# %%
bmgt_gender_2024 = bmgt_gender[bmgt_gender["Year"] == 2024]
bmgt_gender_2024["Ratio"] = bmgt_gender_2024["Count"] / bmgt_gender_2024["Count"].sum()
bmgt_gender_2024
# Out:
# /var/folders/r4/b7cllbyj13vbdjbq6fkcw0380000gt/T/ipykernel_16108/2981161081.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bmgt_gender_2024["Ratio"] = bmgt_gender_2024["Count"] / bmgt_gender_2024["Count"].sum()
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count     Ratio
# 17  2024                 Female                     Female   1505  0.485797
# 18  2024                   Male                       Male   1589  0.512912
# 19  2024             Non-Binary                 Non-Binary      4  0.001291

# %%
computing_gender_combined = pd.concat([jour_gender,cmns_gender,info_gender,bmgt_gender])

# %%
info_gender_2024 = info_gender[info_gender['Year'] == 2024]
info_gender_2024

info_gender_2024['Ratio'] = info_gender_2024['Count'] / info_gender_2024['Count'].sum()
info_gender_2024
# Out:
# /var/folders/r4/b7cllbyj13vbdjbq6fkcw0380000gt/T/ipykernel_16108/1516510231.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_gender_2024['Ratio'] = info_gender_2024['Count'] / info_gender_2024['Count'].sum()
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count     Ratio
# 17  2024                 Female                     Female    767  0.362476
# 18  2024                   Male                       Male   1342  0.634216
# 19  2024             Non-Binary                 Non-Binary      7  0.003308

# %%
jour_gender_2024 = jour_gender[jour_gender['Year'] == 2024]
jour_gender_2024

jour_gender_2024['Ratio'] = jour_gender_2024['Count'] / jour_gender_2024['Count'].sum()
jour_gender_2024
# Out:
# /var/folders/r4/b7cllbyj13vbdjbq6fkcw0380000gt/T/ipykernel_16108/2142598723.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jour_gender_2024['Ratio'] = jour_gender_2024['Count'] / jour_gender_2024['Count'].sum()
#     Year Gender (Old Reporting) Gender (Current Reporting)  Count     Ratio
# 17  2024                 Female                     Female    235  0.591940
# 18  2024                   Male                       Male    161  0.405542
# 19  2024             Non-Binary                 Non-Binary      1  0.002519
